# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt

# %%
# get the response in the form of html
import requests

response = requests.get("https://en.wikipedia.org/wiki/List_of_presidents_of_the_United_States") # URL of the data being scraped

print(f"{response.status_code}: {response.reason}")

response = requests.get("https://en.wikipedia.org/wiki/List_of_presidents_of_the_United_States") # The previous and next few lines are testing to make sure the data is downloadable

print(f"{response.status_code}: {response.reason}")
# Out:
# 200: OK
# 200: OK

# %%
presidents_page = requests.get("https://en.wikipedia.org/wiki/List_of_presidents_of_the_United_States") # get url
# scrape webpage
from bs4 import BeautifulSoup 

presidents_page_soup = BeautifulSoup(presidents_page.content, "html.parser") #This ensures the scraping of the webpage turning it into an object
type(presidents_page_soup)
# Out:
# bs4.BeautifulSoup

# %%
# parse data from the html into beautifulsoup
soup = BeautifulSoup(response.text, 'html.parser') 
presidentstable=soup.find('table',{'class':"wikitable"})

# %%
print(presidentstable) #this will give us the code used to make the table on the website
# Out:
# <table class="wikitable sortable" style="text-align:center;">
# <caption><style data-mw-deduplicate="TemplateStyles:r1152813436">.mw-parser-output .sr-only{border:0;clip:rect(0,0,0,0);clip-path:polygon(0px 0px,0px 0px,0px 0px);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px;white-space:nowrap}</style><span class="sr-only">List of presidents of the United States from 1789 – till date.</span>
# </caption>
# <tbody><tr>
# <th scope="col"><abbr title="Number">No.</abbr><sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[a]</a></sup>
# </th>
# <th class="unsortable" scope="col">Portrait
# </th>
# <th scope="col">Name<br/><span style="font-size:85%;">(Birth–Death)</span>
# </th>
# <th class="unsortable" scope="col">Term<sup class="reference" id="cite_ref-FOOTNOTELOCwhitehouse.gov_15-0"><a href="#cite_note-FOOTNOTELOCwhitehouse.gov-15">[14]</a></sup>
# </th>
# ...

# %%
df=pd.read_html(str(presidentstable))
# convert list to dataframe
df=pd.read_html(str(presidentstable)) # importing pandas to create the dataframe
df=pd.DataFrame(df[0])
df
# Out:
# /var/folders/4b/c37vg5xd4hv3y_rs7bp5zkrh0000gn/T/ipykernel_60372/3855192993.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df=pd.read_html(str(presidentstable))
# /var/folders/4b/c37vg5xd4hv3y_rs7bp5zkrh0000gn/T/ipykernel_60372/3855192993.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df=pd.read_html(str(presidentstable)) # importing pandas to create the dataframe
#     No.[a]  Portrait                       Name (Birth–Death)  \
# 0        1       NaN       George Washington (1732–1799) [17]
# 1        2       NaN              John Adams (1735–1826) [19]
# 2        3       NaN        Thomas Jefferson (1743–1826) [21]
# 3        4       NaN           James Madison (1751–1836) [22]
# ...

# %%
df1 = df[['Name (Birth–Death)','Term[14]']] # I only want to see the columns of the dataframe that indicate the presidents name and term length in years, so I trimmed it
print(df1)
# Out:
#                          Name (Birth–Death)  \
# 0        George Washington (1732–1799) [17]
# 1               John Adams (1735–1826) [19]
# 2         Thomas Jefferson (1743–1826) [21]
# 3            James Madison (1751–1836) [22]
# 4             James Monroe (1758–1831) [24]
# 5        John Quincy Adams (1767–1848) [25]
# 6           Andrew Jackson (1767–1845) [28]
# 7         Martin Van Buren (1782–1862) [29]
# 8   William Henry Harrison (1773–1841) [30]
# 9               John Tyler (1790–1862) [31]
# 10           James K. Polk (1795–1849) [34]
# 11          Zachary Taylor (1784–1850) [35]
# 12        Millard Fillmore (1800–1874) [36]
# 13         Franklin Pierce (1804–1869) [38]
# 14          James Buchanan (1791–1868) [39]
# 15         Abraham Lincoln (1809–1865) [40]
# 16          Andrew Johnson (1808–1875) [42]
# 17        Ulysses S. Grant (1822–1885) [43]
# 18     Rutherford B. Hayes (1822–1893) [44]
# 19       James A. Garfield (1831–1881) [45]
# ...
